# %%
import pandas as pd

# File path to the CSV file
file_path = 'https://raw.githubusercontent.com/guzmanwolfrank/Data-SQL/BankSQL/BankSQL/data/banking_data.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Define a mapping dictionary for full state names to abbreviated forms
state_mapping = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# Map full state names to abbreviated forms in the StateID column
df['StateID'] = df['StateID'].map(state_mapping)

# Save the modified DataFrame to a new CSV file
output_file = 'banking_data.csv'
df.to_csv(output_file, index=False)

# Display the modified DataFrame
display(df)

# Print the absolute path where the CSV file is stored
import os
csv_file_path = os.path.abspath(output_file)
print(f"The CSV file is stored at: {csv_file_path}")
# Out:
#     Record_No   TransactionID       AccountID TransactionDate   Amount  \
# 0           1   TR00000000001  760-1866-G2401      2024-02-07  1872.53
# 1           2   TR00000000002  782-7116-Q1889      2024-04-28  6108.37
# 2           3   TR00000000003  558-2810-K1030      2024-04-04  5932.84
# 3           4   TR00000000004  900-6704-K6834      2024-03-09  2294.56
# 4           5   TR00000000005  556-5707-E8451      2024-02-09   911.11
# ..        ...             ...             ...             ...      ...
# 95         96   TR00000000096  832-8580-U7086      2024-04-02  3172.42
# 96         97   TR00000000097  825-8031-N3078      2024-03-11  6490.33
# 97         98   TR00000000098  480-9204-P9860      2024-04-12  3493.94
# 98         99   TR00000000099  573-3488-B8844      2024-01-04   297.06
# 99        100  TR000000000100  155-6944-T2082      2024-02-17   385.72
#
#    TransactionType First Name Last Name         VendorID     FeeID  ...  \
# ...
